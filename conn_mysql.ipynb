# %%
# librerias analytics
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# librerias db
import boto3
import psycopg2
import pymysql
import configparser

# librerias para generar datos
import random
from faker import Faker
from datetime import datetime

# referencias de archivos
import constants as cons
import ddl

# %%
config = configparser.ConfigParser()
config.read(cons.CONFIG_FILE)
# Out:
# ['config.cfg']

# %%
rds_conn = boto3.client(
    'rds',
    aws_access_key_id=config.get(cons.USER, cons.ACCESS_KEY),
    aws_secret_access_key=config.get(cons.USER, cons.SECRET_KEY),
    region_name='us-east-2'
)

# %%
rds_instances_ids = []
aws_response = rds_conn.describe_db_instances()

for db_instance in aws_response['DBInstances']:
    db_instance_identifier = db_instance['DBInstanceIdentifier']
    db_engine = db_instance['Engine']
    if (db_engine == 'mysql'):
      aws_mysql = db_instance
    else:
      aws_postgres = db_instance
    print(f"La instancia '{db_instance_identifier}' utiliza el motor de base de datos '{db_engine}'")
# Out:
# La instancia 'pj-final-db-v' utiliza el motor de base de datos 'mysql'

# %% [markdown]
# ## Instancia MySQL

# %%
try: 
    response = rds_conn.create_db_instance(
        DBInstanceIdentifier=config.get(cons.DB, cons.INSTANCE_ID),
        DBName=config.get(cons.DB, cons.DB_NAME),
        MasterUsername=config.get(cons.DB, cons.DB_USERNAME),
        MasterUserPassword=config.get(cons.DB, cons.DB_PASSWORD),
        Port=int(config.get(cons.DB, cons.PORT)),
        DBInstanceClass= cons.INSTANCE_CLASS,
        Engine=cons.ENGINE,
        PubliclyAccessible=True,
        AllocatedStorage=cons.ALLOC_STORAGE,
        VpcSecurityGroupIds=[config.get(cons.VPC, cons.SEC_GROUP)]
    )
except rds_conn.exceptions.DBInstanceAlreadyExistsFault:
    print("La instancia ya existe")
except Exception as ex:
    print("Error!! ", ex)
# Out:
# La instancia ya existe

# %% [markdown]
# # Hostname de instancia

# %%
try:
    instance = rds_conn.describe_db_instances(
        DBInstanceIdentifier=config.get(cons.DB, cons.INSTANCE_ID)
    )
    RDS_HOSTNAME = instance.get('DBInstances')[0].get('Endpoint').get('Address')
    print(RDS_HOSTNAME)
except Exception as ex:
    print("Error!! ", ex)
# Out:
# pj-final-db-v.cq2nw4bt4dzn.us-east-2.rds.amazonaws.com

# %% [markdown]
# # Conexion y crear tablas

# %%
import ddl

# %%
host = config.get('DB', 'DB_INSTANCE_ID')
user = config.get('DB', 'DB_USERNAME') 
password = config.get('DB', 'DB_PASSWORD')
database = config.get('DB', 'DB_NAME')
port = int(config.get('DB', 'DB_PORT'))

conn = pymysql.connect(host=RDS_HOSTNAME,
                       user=user,
                       password=password,
                       database=database,
                       port=port)

# %%
def create_table(table_name):
    try:
        ddl_statement = getattr(ddl, f'DDL_CREATE_{table_name.upper()}')
        cursor = conn.cursor()
        cursor.execute(ddl_statement)
        conn.commit()
        print(f"Table {table_name} created successfully")
    except Exception as ex:
        print(f"Table {table_name} not created", ex)

# %%
tables = ['categoria', 'articulo', 'persona', 'rol', 'usuario', 'ingreso', 'venta', 'detalle_venta', 'detalle_ingreso']
for table in tables:
    create_table(table)
# Out:
# Table categoria created successfully
# Table articulo created successfully
# Table persona created successfully
# Table rol created successfully
# Table usuario created successfully
# Table ingreso created successfully
# Table venta created successfully
# Table detalle_venta created successfully
# Table detalle_ingreso created successfully

# %% [markdown]
# # Generate Mock Data

# %% [markdown]
# ## funciones para generar datos

# %%
fake = Faker()

# %%
# metodo para generar varias palabras random para los campos de descripcion
def generate_text(words_number = 20):
  words = fake.words(
      nb = words_number,
      ext_word_list = None,
      unique = False
  )
  text = ' '.join(words).lower()
  return text

# %%
# categorias
def generate_categorias():

  category_data = []

  category_names = [
    "Automotive", "Baby", "Beauty", "Books", "Clothing",
    "Computers", "Electronics", "Games", "Garden", "Grocery",
    "Health", "Home", "Industrial", "Jewelry", "Kids",
    "Movies", "Music", "Outdoors", "Shoes", "Sports",
    "Tools", "Toys"
    ]  # generated with mockaroo

  for name in category_names:
    nombre = name
    descripcion = generate_text(10)
    estado = random.randint(0, 1)
    # sql = f"INSERT INTO categoria(nombre, descripcion, estado) VALUES ({nombre}, {descripcion}, {estado});"
    category_data.append((nombre, descripcion, estado))

  return category_data

# %%
# articulos
def generate_articulos():

  product_data = []

  for i in range(200):
    idcategoria = random.randint(1, 22)
    codigo = fake.ean13(prefixes=('45', '55'))
    nombre = fake.word().capitalize()
    precio_venta = round(random.uniform(1.0, 500.0), 2)
    stock = random.randint(0, 1000)
    descripcion = generate_text(10)
    imagen = fake.file_name(category = 'image')
    estado = random.randint(0, 1)

    product_data.append( (idcategoria, codigo, nombre, precio_venta, stock, descripcion, imagen, estado) )

  return product_data

# %%
# roles
def generate_roles():

  role_data = []

  roles = ['Administrator', 'Manager', 'Cashier']
  for role in roles:
    nombre = role
    descripcion = generate_text(5)
    estado = random.randint(0, 1)
    role_data.append( (nombre, descripcion, estado) )

  return role_data

# %%
# usuarios, 50 en total
def generate_usuarios():

  user_data = []

  for i in range(50):
    nombre = fake.name()
    tipo_documento = random.choice(['DPI', 'Passport'])
    direccion = fake.street_address()
    telefono = fake.phone_number()
    email = fake.email()
    clave = fake.password(length=12, special_chars=True, digits=True, upper_case=True, lower_case=True)
    estado = random.randint(0, 1)

    if i % 25 == 0:
      idrol = 1
    elif i % 10 == 0:
      idrol = 2
    else:
      idrol = 3

    if tipo_documento == 'Passport':
      num_documento = fake.passport_number()
    else:
      num_documento = fake.random_number(digits=13)

    user_data.append( (idrol, nombre, tipo_documento, num_documento, direccion, telefono, email, clave, estado) )

  return user_data

# %%
# personas , 100 proveedores y 500 clientes
def generate_personas():

  personas_data = []

  # provedores
  for i in range(100):
    tipo_persona = 'Supplier'
    nombre = fake.name()
    tipo_documento = random.choice(['DPI', 'Passport'])
    direccion = fake.street_address()
    telefono = fake.phone_number()
    email = fake.email()

    if tipo_documento == 'Passport':
      num_documento = fake.passport_number()
    else:
      num_documento = fake.random_number(digits=13)

    personas_data.append( (tipo_persona, nombre, tipo_documento, num_documento, direccion, telefono, email) )

  # clientes
  for i in range(500):
    tipo_persona = 'Client'
    nombre = fake.name()
    tipo_documento = random.choice(['DPI', 'Passport'])
    direccion = fake.street_address()
    telefono = fake.phone_number()
    email = fake.email()

    if tipo_documento == 'Passport':
      num_documento = fake.passport_number()
    else:
      num_documento = fake.random_number(digits=13)

    personas_data.append( (tipo_persona, nombre, tipo_documento, num_documento, direccion, telefono, email) )

  return personas_data

# %%
# ingresos
def generate_ingreso():
    ingreso_data = []

    for i in range(150):
        idproveedor = random.randint(1, 100)
        idusuario = random.randint(1, 50)
        tipo_comprobante = random.choice(['Invoice', 'Receipt'])
        serie_comprobante = fake.bothify(text='?').upper()
        num_comprobante = serie_comprobante + fake.bothify(text='######')
        fecha = fake.date_between(start_date = datetime(2020, 1, 1).date(), end_date = datetime(2023, 12, 31).date())
        impuesto = round(random.uniform(0, 15), 2)
        total = round(random.uniform(100, 10000), 2)
        estado = random.choice(['Processed', 'Cancelled', 'Pending'])

        ingreso_data.append((idproveedor, idusuario, tipo_comprobante, serie_comprobante, num_comprobante, fecha, impuesto, total, estado))

    return ingreso_data

# %%
# detalle ingresos
def generate_detalle_ingreso():
    detalle_data = []

    for i in range(150):
        idingreso = random.randint(1, 150)
        idarticulo = random.randint(1, 300)
        cantidad = random.randint(1, 2000)
        precio = round(random.uniform(1.0, 1000.0), 2)

        detalle_data.append((idingreso, idarticulo, cantidad, precio))

    return detalle_data

# %%
# ventas
def generate_venta():
    venta_data = []

    for i in range(1000):
        idcliente = random.randint(110, 600)
        idusuario = random.randint(1, 50)
        tipo_comprobante = random.choice(['Invoice', 'Receipt'])
        serie_comprobante = fake.bothify(text='?').upper()
        num_comprobante = serie_comprobante + fake.bothify(text='######')
        fecha = fake.date_between(start_date = datetime(2020, 1, 1).date(), end_date = datetime(2023, 12, 31).date())
        impuesto = round(random.uniform(0, 15), 2)
        total = round(random.uniform(100, 10000), 2)
        estado = random.choice(['Processed', 'Cancelled', 'Pending'])

        venta_data.append((idcliente, idusuario, tipo_comprobante, serie_comprobante, num_comprobante, fecha, impuesto, total, estado))

    return venta_data

# %%
# detalle ventas

def generate_detalle_venta():
    detalle_venta_data = []

    for i in range(10000):
        idventa = random.randint(1, 1000)
        idarticulo = random.randint(1, 300)
        cantidad = random.randint(1, 10)
        precio = round(random.uniform(1.0, 750.0), 2)
        descuento = round(precio * random.uniform(0.05, 0.25), 2)

        detalle_venta_data.append((idventa, idarticulo, cantidad, precio, descuento))

    return detalle_venta_data

# %% [markdown]
# ## Generar los datos

# %%
# generate data

category_data = generate_categorias()
product_data = generate_articulos()
role_data = generate_roles()
user_data = generate_usuarios()
personas_data = generate_personas()
ingreso_data = generate_ingreso()
detalle_data = generate_detalle_ingreso()
venta_data = generate_venta()
detalle_venta_data = generate_detalle_venta()

# %% [markdown]
# ## Funcion de Bulk Insert

# %%
def bulk_insert(conn, insert_query, data_list):
    cursor = conn.cursor()  
    try:
        # bulk insert
        cursor.executemany(insert_query, data_list)
        conn.commit()
        print("Bulk data inserted successfully")
    except pymysql.Error as error:
        print("Error inserting bulk data", error)
    finally:
        cursor.close()

# %% [markdown]
# ## Queries de insert

# %%
# QUERIES DE INSERTAR PARA MYSQL

insert_MYSQL_categoria = """
    INSERT INTO categoria (nombre, descripcion, estado)
    VALUES (%s, %s, %s)
"""

insert_MYSQL_articulo = """
    INSERT INTO articulo (idcategoria, codigo, nombre, precio_venta, stock, descripcion, imagen, estado)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
"""

insert_MYSQL_persona = """
    INSERT INTO persona (tipo_persona, nombre, tipo_documento, num_documento, direccion, telefono, email)
    VALUES (%s, %s, %s, %s, %s, %s, %s)
"""

insert_MYSQL_rol = """
    INSERT INTO rol (nombre, descripcion, estado)
    VALUES (%s, %s, %s)
"""

insert_MYSQL_usuario = """
    INSERT INTO usuario (idrol, nombre, tipo_documento, num_documento, direccion, telefono, email, clave, estado)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

insert_MYSQL_ingreso = """
    INSERT INTO ingreso (idproveedor, idusuario, tipo_comprobante, serie_comprobante, num_comprobante, fecha, impuesto, total, estado)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

insert_MYSQL_venta = """
    INSERT INTO venta (idcliente, idusuario, tipo_comprobante, serie_comprobante, num_comprobante, fecha, impuesto, total, estado)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

insert_MYSQL_detalle_venta = """
    INSERT INTO detalle_venta (idventa, idarticulo, cantidad, precio, descuento)
    VALUES (%s, %s, %s, %s, %s)
"""

insert_MYSQL_detalle_ingreso = """
    INSERT INTO detalle_ingreso (idingreso, idarticulo, cantidad, precio)
    VALUES (%s, %s, %s, %s)
"""

# %% [markdown]
# ## Insertar datos a la DB

# %%
bulk_insert(conn, insert_MYSQL_categoria, category_data)
bulk_insert(conn, insert_MYSQL_articulo, product_data)
bulk_insert(conn, insert_MYSQL_rol, role_data)
bulk_insert(conn, insert_MYSQL_usuario, user_data)
bulk_insert(conn, insert_MYSQL_persona, personas_data)
bulk_insert(conn, insert_MYSQL_ingreso, ingreso_data)
bulk_insert(conn, insert_MYSQL_detalle_ingreso, detalle_data)
bulk_insert(conn, insert_MYSQL_venta, venta_data)
bulk_insert(conn, insert_MYSQL_detalle_venta, detalle_venta_data)
# Out:
# Bulk data inserted successfully
# Bulk data inserted successfully
# Bulk data inserted successfully
# Bulk data inserted successfully
# Bulk data inserted successfully
# Bulk data inserted successfully
# Bulk data inserted successfully
# Bulk data inserted successfully
# Bulk data inserted successfully

# %% [markdown]
# ## SELECT PARA VERIFICAR

# %%
def select_table(table_name):

# %%
SELECT_CATEGORIA = "SELECT * FROM categoria;"
SELECT_ARTICULO = "SELECT * FROM articulo;"
SELECT_PERSONA = "SELECT * FROM persona;"
SELECT_ROL = "SELECT * FROM rol;"
SELECT_USUARIO = "SELECT * FROM usuario;"
SELECT_INGRESO = "SELECT * FROM ingreso;"
SELECT_VENTA = "SELECT * FROM venta;"
SELECT_DETALLE_VENTA = "SELECT * FROM detalle_venta;"
SELECT_DETALLE_INGRESO = "SELECT * FROM detalle_ingreso;"

# %%
def select_table(conn, ddl_statement):
    try:
        cursor = conn.cursor()
        cursor.execute(ddl_statement)
        results = cursor.fetchall()
        if results:
            print(f"\n{ddl_statement}\n")
            for row in results:
                print(row)
        else:
            print("No hay datos.")
    except pymysql.Error as error:
        print(f"Error: {error}")

# %%
select_table(conn, SELECT_CATEGORIA)
select_table(conn, SELECT_ARTICULO)
select_table(conn, SELECT_PERSONA)
select_table(conn, SELECT_ROL)
select_table(conn, SELECT_USUARIO)
select_table(conn, SELECT_INGRESO)
select_table(conn, SELECT_VENTA)
select_table(conn, SELECT_DETALLE_VENTA)
select_table(conn, SELECT_DETALLE_INGRESO)
# Out:
# SELECT * FROM categoria;
#
# (1, 'Automotive', 'bed media employee that student probably tell board another listen', b'\x01')
# (2, 'Baby', 'i personal federal investment dinner fine message section responsibility plant', b'\x00')
# (3, 'Beauty', 'modern simple drug draw peace today same join these customer', b'\x00')
# (4, 'Books', 'sound per money son officer respond its certainly political lawyer', b'\x01')
# (5, 'Clothing', 'edge sense need hard one charge break service fill evening', b'\x00')
# (6, 'Computers', 'natural investment everybody guy course wall commercial seven before until', b'\x00')
# (7, 'Electronics', 'feel company bed next quickly staff despite recent expert season', b'\x00')
# (8, 'Games', 'control reduce anything many lot current perform central create scene', b'\x01')
# (9, 'Garden', 'just after teach friend week itself or to mean wear', b'\x01')
# (10, 'Grocery', 'red truth hand author important have ok old mission issue', b'\x00')
# (11, 'Health', 'opportunity exist nice watch feel image test consider avoid approach', b'\x00')
# (12, 'Home', 'hour point collection room design behind sort baby including almost', b'\x01')
# (13, 'Industrial', 'power it claim natural couple exist place help alone admit', b'\x00')
# (14, 'Jewelry', 'enough explain their toward eat charge generation nearly ask single', b'\x01')
# (15, 'Kids', 'skin this difficult customer investment beyond court everyone can during', b'\x00')
# (16, 'Movies', 'response daughter against child many put suggest receive out owner', b'\x00')
# (17, 'Music', 'maybe world hope discussion wear produce decide enjoy make executive', b'\x00')
# (18, 'Outdoors', 'agree unit send raise explain suggest catch six board so', b'\x01')
# (19, 'Shoes', 'on series look star every for threat response generation subject', b'\x00')
# (20, 'Sports', 'trouble story own letter wish unit almost behind strong speech', b'\x01')
# (21, 'Tools', 'approach ever option shake board major us most son language', b'\x01')
# (22, 'Toys', 'interest policy six relate different knowledge these adult over million', b'\x01')
#
# SELECT * FROM articulo;
#
# (1, 18, '4543943707880', 'Condition', Decimal('294.28'), 925, 'fact news feeling particularly stop small window leg north any', 'usually.png', b'\x00')
# (2, 22, '4585395787409', 'Own', Decimal('160.84'), 169, 'together western start station experience during very maintain pattern believe', 'possible.tiff', b'\x01')
# (3, 1, '4575542654579', 'Fact', Decimal('400.38'), 313, 'step fund military floor draw politics policy ready media scientist', 'will.tiff', b'\x01')
# (4, 7, '4568875535899', 'Several', Decimal('225.02'), 805, 'despite per near cup grow something particular choice indeed international', 'someone.jpg', b'\x01')
# (5, 17, '5530444973356', 'Value', Decimal('247.81'), 682, 'for often itself assume simple edge as unit prepare meeting', 'across.jpg', b'\x00')
# (6, 10, '4559193373089', 'Visit', Decimal('434.56'), 710, 'daughter even identify discuss claim challenge participant rule school small', 'career.jpeg', b'\x01')
# (7, 7, '4562313400299', 'Service', Decimal('368.61'), 408, 'team president research indicate individual white avoid bank always degree', 'plant.png', b'\x00')
# (8, 10, '4505404194844', 'Board', Decimal('448.58'), 257, 'pull well do control stop color drop dog down wait', 'notice.png', b'\x01')
# (9, 22, '4511457342576', 'Close', Decimal('44.20'), 702, 'nothing support stock fight animal daughter just tv about toward', 'deep.png', b'\x01')
# (10, 11, '5550282681138', 'Nothing', Decimal('254.88'), 806, 'push pretty heavy hair daughter let live eye collection low', 'half.png', b'\x00')
# (11, 9, '5502252777976', 'While', Decimal('396.04'), 437, 'hundred main wall born along summer executive focus eight still', 'idea.jpeg', b'\x00')
# (12, 8, '4572177174939', 'Either', Decimal('232.54'), 752, 'local few another capital deep choose tax high hit car', 'area.tiff', b'\x00')
# (13, 9, '5513998170228', 'Cold', Decimal('46.71'), 729, 'system personal new reflect economic protect use young sound thing', 'toward.jpeg', b'\x01')
# (14, 12, '4547057027896', 'Friend', Decimal('172.08'), 352, 'weight sell see beat community former them then land per', 'main.bmp', b'\x00')
# (15, 15, '4516520946422', 'Outside', Decimal('212.81'), 233, 'see deep candidate newspaper free rock body down name plant', 'industry.tiff', b'\x01')
# (16, 2, '5507007018472', 'Ago', Decimal('41.87'), 631, 'focus that performance necessary yard service understand step example agreement', 'system.jpeg', b'\x00')
# (17, 8, '4527735659311', 'Wife', Decimal('344.52'), 540, 'others determine eat out model use response season hair there', 'order.png', b'\x00')
# (18, 15, '4519096356510', 'Main', Decimal('128.74'), 235, 'detail outside west require necessary must management available south home', 'establish.png', b'\x00')
# (19, 20, '5580157739251', 'Capital', Decimal('438.54'), 545, 'effort attorney two own various different share beyond than mean', 'performance.jpg', b'\x01')
# (20, 5, '5558528072214', 'Require', Decimal('92.11'), 952, 'moment education society place wall art statement management that prevent', 'thank.jpeg', b'\x00')
# (21, 9, '4567525280189', 'Already', Decimal('163.62'), 237, 'form indicate style talk color western animal career team cut', 'clearly.jpg', b'\x00')
# (22, 9, '4571993525420', 'Foreign', Decimal('114.68'), 511, 'baby threat reveal minute successful six executive skill policy culture', 'feeling.bmp', b'\x00')
# (23, 22, '4569071293224', 'Recent', Decimal('183.55'), 551, 'its together perform father industry will data almost some appear', 'then.jpeg', b'\x00')
# (24, 15, '5520134377083', 'Stage', Decimal('31.13'), 57, 'drug deep around white just husband where firm budget similar', 'radio.jpg', b'\x01')
# (25, 16, '5521745326712', 'His', Decimal('202.48'), 363, 'fall green building across me along thought foot chance ok', 'theory.png', b'\x00')
# (26, 7, '4598235722300', 'Week', Decimal('490.93'), 315, 'reduce carry ground course expert movie maybe owner mention whether', 'rock.jpg', b'\x01')
# (27, 18, '5531466383260', 'Store', Decimal('195.35'), 356, 'employee soon discussion few including toward increase analysis add though', 'owner.jpeg', b'\x00')
# (28, 22, '4510148637083', 'Turn', Decimal('111.29'), 279, 'science plan public blue clearly want within son provide listen', 'cut.gif', b'\x00')
# (29, 8, '5510764441254', 'Father', Decimal('293.51'), 459, 'kitchen vote water admit organization treatment own coach art establish', 'white.bmp', b'\x00')
# (30, 12, '5502046244882', 'Cell', Decimal('373.55'), 514, 'answer question person later according technology interest lot billion price', 'picture.png', b'\x01')
# (31, 21, '4545403704828', 'Right', Decimal('74.18'), 565, 'on we finish kind similar also challenge open foot example', 'with.bmp', b'\x00')
# (32, 18, '5557613778109', 'Leg', Decimal('197.11'), 300, 'attention media position number really good never congress thus republican', 'here.gif', b'\x01')
# (33, 22, '4568057674880', 'Direction', Decimal('295.91'), 585, 'free new their treat together century fly dream view nature', 'site.jpeg', b'\x00')
# (34, 9, '5549456768089', 'Include', Decimal('462.67'), 152, 'stop hundred loss brother sit indeed professional total avoid to', 'garden.jpg', b'\x01')
# (35, 16, '5564675628327', 'System', Decimal('450.23'), 693, 'travel throughout money discussion head site issue similar concern service', 'key.gif', b'\x00')
# (36, 11, '4587481440021', 'Figure', Decimal('258.34'), 356, 'budget foreign scene beat blue specific economy anyone research economy', 'back.gif', b'\x00')
# (37, 19, '4584898697765', 'Center', Decimal('307.61'), 259, 'its cause member pm break degree build house instead address', 'feel.gif', b'\x00')
# (38, 4, '5593696499425', 'Mother', Decimal('37.60'), 656, 'realize agreement fight know theory music author player reveal participant', 'write.jpg', b'\x00')
# (39, 18, '5532266192328', 'Agent', Decimal('450.56'), 564, 'morning certain service ground debate environment whom send well lawyer', 'girl.jpg', b'\x01')
# (40, 16, '4594406072731', 'Five', Decimal('2.38'), 733, 'baby system collection style yard woman represent south do agree', 'company.gif', b'\x00')
# (41, 14, '5539079619387', 'Just', Decimal('349.33'), 484, 'push back end middle resource can project table wait fall', 'drive.gif', b'\x01')
# (42, 5, '5503494450566', 'End', Decimal('429.82'), 712, 'street girl boy book never will term say remember final', 'when.tiff', b'\x00')
# (43, 6, '4536810014778', 'Relationship', Decimal('230.88'), 80, 'too coach government part cultural impact his mr least couple', 'job.jpeg', b'\x00')
# (44, 3, '4502138351246', 'Civil', Decimal('463.06'), 956, 'on produce care respond part good again place charge event', 'open.bmp', b'\x00')
# (45, 7, '5567924768577', 'Reach', Decimal('14.37'), 942, 'factor use nice need same early property kitchen happy task', 'color.gif', b'\x01')
# (46, 19, '5594636131801', 'Information', Decimal('103.23'), 378, 'serious reflect where live push no send assume degree admit', 'red.gif', b'\x00')
# (47, 21, '4598519400283', 'Edge', Decimal('18.61'), 845, 'skin congress employee year production yard ever although usually heart', 'success.jpg', b'\x00')
# (48, 19, '4595118404735', 'Trip', Decimal('312.03'), 33, 'cold nothing we writer boy mission opportunity trip debate few', 'smile.jpeg', b'\x00')
# (49, 13, '4583306797486', 'Physical', Decimal('252.49'), 402, 'wife let inside outside watch everybody either least manager whose', 'respond.bmp', b'\x00')
# (50, 5, '5509537387196', 'Item', Decimal('246.87'), 312, 'same police nor by science law red article share magazine', 'chance.bmp', b'\x01')
# (51, 18, '4571304993863', 'Defense', Decimal('196.11'), 282, 'hot picture it then service technology indicate itself around pressure', 'reason.png', b'\x00')
# (52, 15, '4553103999581', 'Heart', Decimal('482.49'), 469, 'prove room take glass hour issue individual knowledge people save', 'message.jpg', b'\x00')
# (53, 12, '5523848218055', 'Show', Decimal('242.66'), 360, 'guy worker base window institution during appear window deep floor', 'party.bmp', b'\x01')
# (54, 16, '4511495910492', 'Wish', Decimal('46.42'), 751, 'field professional indeed enjoy middle conference support along southern maintain', 'phone.tiff', b'\x01')
# (55, 13, '5529442653872', 'Push', Decimal('75.55'), 923, 'local sell memory drug forget we parent population pull quality', 'risk.bmp', b'\x01')
# (56, 5, '4565390088008', 'Economy', Decimal('46.09'), 719, 'matter experience memory wind right sometimes so morning administration by', 'toward.jpg', b'\x00')
# (57, 22, '4569551838136', 'Out', Decimal('392.53'), 68, 'mind professional ability method move there even next sure edge', 'stop.gif', b'\x01')
# (58, 9, '5591458978959', 'Forget', Decimal('19.41'), 209, 'least section relationship management wait any open everything could suddenly', 'company.png', b'\x00')
# (59, 8, '4543391664223', 'Whose', Decimal('195.89'), 255, 'red sound reveal knowledge eat leader part day kid remain', 'happy.bmp', b'\x01')
# (60, 10, '4523920899173', 'Just', Decimal('199.98'), 183, 'actually democrat chair detail fire join wish million above american', 'his.png', b'\x01')
# (61, 19, '5558833170018', 'But', Decimal('432.35'), 456, 'own best certainly structure same word enter point at character', 'tonight.tiff', b'\x01')
# (62, 18, '4547000802259', 'Operation', Decimal('85.24'), 918, 'first study sit but both take expect heavy watch light', 'few.tiff', b'\x01')
# (63, 8, '4550348705021', 'Food', Decimal('452.64'), 693, 'college effort social yard player remember school book act success', 'team.png', b'\x00')
# (64, 15, '5573231811240', 'Hotel', Decimal('391.61'), 206, 'develop none senior long country happen enter trouble short represent', 'rest.gif', b'\x00')
# (65, 11, '5554779487869', 'Eat', Decimal('146.14'), 457, 'happen range city plan forward message indicate everybody fish worker', 'local.gif', b'\x01')
# (66, 16, '4509114411260', 'Board', Decimal('422.04'), 484, 'compare movie letter specific second professor project interview writer and', 'occur.bmp', b'\x00')
# (67, 5, '4575001440811', 'Individual', Decimal('83.19'), 273, 'choice choose every data close talk meet throw result prevent', 'nearly.tiff', b'\x00')
# (68, 14, '5501682199785', 'Turn', Decimal('297.68'), 923, 'choice summer throughout product voice increase notice spring senior week', 'best.jpg', b'\x01')
# (69, 22, '4533355185895', 'Many', Decimal('2.65'), 762, 'more machine throw too very throughout over three it factor', 'face.gif', b'\x00')
# (70, 10, '5571918691802', 'Perform', Decimal('330.36'), 337, 'dark keep expect now bring especially morning remain outside fund', 'notice.tiff', b'\x01')
# (71, 22, '5519246080745', 'Ask', Decimal('94.78'), 970, 'building cut impact half citizen goal show center say become', 'perhaps.jpeg', b'\x01')
# (72, 9, '4527005817410', 'Ahead', Decimal('413.33'), 498, 'may interesting single team consumer opportunity close pick challenge sometimes', 'view.bmp', b'\x01')
# (73, 21, '4578174006341', 'Off', Decimal('465.96'), 700, 'discuss close medical page value heart night feeling bag wait', 'himself.png', b'\x01')
# (74, 9, '5528712699299', 'Themselves', Decimal('217.54'), 12, 'financial according career make drug couple subject particular manager share', 'tough.png', b'\x01')
# (75, 14, '4552300113080', 'Prepare', Decimal('496.27'), 253, 'system baby exactly quite activity argue my sea job loss', 'full.jpg', b'\x00')
# (76, 14, '5554619321490', 'Likely', Decimal('400.87'), 742, 'history east develop word word probably make cost share pressure', 'our.jpeg', b'\x01')
# (77, 12, '5519204273202', 'Contain', Decimal('448.40'), 546, 'area half appear cell them friend when might thus organization', 'area.png', b'\x00')
# (78, 10, '4526715022329', 'Again', Decimal('229.58'), 794, 'major now radio improve scientist agency economic responsibility treatment strategy', 'street.gif', b'\x00')
# (79, 3, '4592536647386', 'Over', Decimal('77.53'), 804, 'three upon fill pick mrs drug energy voice ago red', 'bit.bmp', b'\x01')
# (80, 20, '5526213113443', 'Improve', Decimal('110.45'), 11, 'international republican to street avoid country sell budget special quality', 'moment.gif', b'\x01')
# (81, 8, '4545111493762', 'Newspaper', Decimal('439.84'), 398, 'sometimes determine off wonder position evidence another late either run', 'rate.jpg', b'\x00')
# (82, 1, '4558944983218', 'Standard', Decimal('216.93'), 697, 'technology artist pull sound fish start she however mean thought', 'first.png', b'\x00')
# (83, 17, '5516995966870', 'Five', Decimal('334.16'), 127, 'candidate president on total wife property work sea party check', 'common.jpeg', b'\x01')
# (84, 14, '5529446498325', 'Whose', Decimal('323.20'), 36, 'security wife very fish think security myself leave seven factor', 'four.bmp', b'\x01')
# (85, 11, '4569858219386', 'Turn', Decimal('455.80'), 299, 'one vote glass direction yeah my type surface create personal', 'rest.jpeg', b'\x00')
# (86, 20, '5565436633833', 'Finish', Decimal('352.79'), 410, 'message wife scientist energy site fish whatever huge then example', 'entire.png', b'\x01')
# (87, 22, '5542275803931', 'Than', Decimal('276.51'), 932, 'court he how know avoid meeting experience shoulder bar pm', 'weight.tiff', b'\x01')
# (88, 4, '4515010817549', 'Might', Decimal('289.00'), 983, 'enjoy crime member save detail food sing because guess expert', 'discuss.bmp', b'\x01')
# (89, 2, '4518988552122', 'Understand', Decimal('184.85'), 606, 'sign anything child enter remain his visit among before wish', 'themselves.jpeg', b'\x00')
# (90, 19, '4566997527549', 'Old', Decimal('457.97'), 194, 'prepare only world increase before return what form court rise', 'official.jpg', b'\x00')
# (91, 14, '5541456033822', 'Coach', Decimal('312.38'), 564, 'also party success air hot card store staff republican ball', 'cost.tiff', b'\x01')
# (92, 12, '5590435114885', 'Away', Decimal('469.07'), 36, 'already agency door history science during seem mention city no', 'person.jpg', b'\x01')
# (93, 16, '5567398434879', 'Education', Decimal('109.67'), 243, 'work claim campaign senior debate enjoy attorney only north draw', 'job.tiff', b'\x01')
# (94, 13, '5532033218374', 'Outside', Decimal('153.01'), 707, 'gas home experience final almost article society product friend position', 'chance.bmp', b'\x00')
# (95, 3, '5527420572283', 'Conference', Decimal('422.89'), 897, 'decade arrive hair deal mission beyond agency school few decide', 'beautiful.tiff', b'\x01')
# (96, 16, '4508791985934', 'Use', Decimal('199.05'), 39, 'authority entire our spring song president travel really range wall', 'store.jpeg', b'\x01')
# (97, 12, '5506039604578', 'Thing', Decimal('394.07'), 716, 'administration pattern girl factor dream purpose rate increase stuff land', 'discussion.gif', b'\x01')
# (98, 21, '5546707301538', 'Space', Decimal('475.63'), 381, 'firm baby really item maintain street lay allow back nation', 'interest.jpeg', b'\x01')
# (99, 8, '4515835996467', 'Friend', Decimal('437.92'), 232, 'such win born million front today use nature cell care', 'certain.jpg', b'\x00')
# (100, 4, '5581749880313', 'Character', Decimal('216.31'), 689, 'yes language focus either way market discussion wide piece draw', 'house.jpeg', b'\x00')
# (101, 11, '4537145892321', 'Place', Decimal('75.33'), 545, 'nation series speech thought address hair sea despite appear join', 'its.png', b'\x01')
# (102, 11, '4500598345683', 'Tend', Decimal('267.98'), 402, 'adult leave professor receive study health few important out perform', 'them.jpeg', b'\x01')
# (103, 13, '5527261315254', 'Traditional', Decimal('461.50'), 281, 'ago class guess about both shoulder ahead american wait kind', 'remain.tiff', b'\x01')
# (104, 18, '5545144263638', 'Baby', Decimal('457.33'), 613, 'network news ten entire party their begin stand indeed end', 'hour.png', b'\x01')
# (105, 3, '5552242356162', 'Learn', Decimal('436.32'), 872, 'center century rest late left control peace director let bad', 'suddenly.jpeg', b'\x00')
# (106, 16, '4524255913473', 'Language', Decimal('358.13'), 160, 'reach audience president bed world thousand nothing return drug small', 'share.jpg', b'\x00')
# (107, 2, '5575280849359', 'Nation', Decimal('304.57'), 151, 'actually various watch him cup west doctor keep economic authority', 'near.gif', b'\x01')
# (108, 9, '5515311106228', 'Past', Decimal('420.47'), 969, 'plan will exactly technology investment specific happen brother wait subject', 'Republican.tiff', b'\x01')
# (109, 15, '5501628479902', 'Current', Decimal('71.28'), 652, 'on have ground moment size do what speech yard goal', 'full.jpg', b'\x00')
# (110, 20, '4545313530180', 'Feel', Decimal('113.92'), 471, 'whole art expert center guess dream answer argue young compare', 'teacher.png', b'\x00')
# (111, 17, '5581004029532', 'Read', Decimal('439.86'), 875, 'more note member sell claim data far imagine far whose', 'poor.jpg', b'\x01')
# (112, 22, '5576969097054', 'Situation', Decimal('157.50'), 800, 'easy including according change town which party party call strategy', 'usually.gif', b'\x01')
# (113, 21, '4508461706203', 'Job', Decimal('299.20'), 76, 'old current hot task middle relate despite along town try', 'process.png', b'\x00')
# (114, 13, '4581744238578', 'Ball', Decimal('382.65'), 193, 'box white congress particular model such others true first number', 'gas.tiff', b'\x01')
# (115, 9, '5578487482312', 'Turn', Decimal('155.24'), 15, 'billion let care true cost town talk surface as purpose', 'top.tiff', b'\x00')
# (116, 10, '5554316001091', 'Name', Decimal('411.89'), 775, 'religious provide job base successful set describe large identify political', 'lay.gif', b'\x01')
# (117, 9, '4528032406493', 'Significant', Decimal('164.34'), 678, 'special standard knowledge development behavior yet his rich number place', 'leave.jpeg', b'\x01')
# (118, 10, '4536346477788', 'South', Decimal('173.78'), 155, 'family order nice prepare establish election bring hour record about', 'job.gif', b'\x01')
# (119, 22, '4556673907161', 'Glass', Decimal('160.68'), 154, 'realize thank nature meet between hotel head process structure detail', 'career.png', b'\x01')
# (120, 8, '4535416361590', 'Clearly', Decimal('228.28'), 274, 'wear any relate beat arm involve local anything institution group', 'phone.bmp', b'\x01')
# (121, 20, '5591096769513', 'Friend', Decimal('317.10'), 983, 'understand practice support term recently job simple executive consider glass', 'record.gif', b'\x00')
# (122, 16, '5526153602519', 'Read', Decimal('434.38'), 140, 'reduce job half and action we century hear seek involve', 'director.png', b'\x00')
# (123, 19, '4539974974391', 'Home', Decimal('372.52'), 78, 'idea lead dream tend concern suffer trip until may blue', 'wall.jpeg', b'\x01')
# (124, 5, '5534734907700', 'Republican', Decimal('428.16'), 857, 'fall million night weight discuss story claim rule late fast', 'factor.jpg', b'\x01')
# (125, 20, '5585677112300', 'Cup', Decimal('496.49'), 216, 'walk light stock parent change line fund foreign beat floor', 'behavior.jpeg', b'\x01')
# (126, 10, '5588124809556', 'Clear', Decimal('263.93'), 512, 'like next she fill rather operation drive three road office', 'receive.gif', b'\x01')
# (127, 2, '4522685925059', 'Several', Decimal('5.51'), 609, 'movie across role though surface onto determine standard real public', 'set.jpeg', b'\x01')
# (128, 2, '5559191722307', 'Magazine', Decimal('181.16'), 691, 'type product shake expert fact bill gun past prove the', 'poor.png', b'\x00')
# (129, 17, '5500637399546', 'Live', Decimal('45.35'), 214, 'receive clear century boy almost special security record fight building', 'sense.bmp', b'\x00')
# (130, 2, '4571943707463', 'Avoid', Decimal('192.03'), 313, 'figure better draw prepare watch single husband popular particular generation', 'college.png', b'\x00')
# (131, 21, '4508056364085', 'Today', Decimal('247.26'), 881, 'officer manager among language or available floor live also share', 'western.jpg', b'\x01')
# (132, 20, '5555779138744', 'Material', Decimal('191.25'), 656, 'second huge science level one capital turn art if race', 'stand.bmp', b'\x00')
# (133, 14, '4555475954847', 'Nature', Decimal('274.06'), 512, 'watch property their administration interest thought investment name at training', 'Mrs.bmp', b'\x01')
# (134, 17, '5504104805646', 'Consider', Decimal('318.41'), 638, 'tend go relate and growth customer soldier thus place black', 'boy.jpg', b'\x01')
# (135, 1, '4574961816391', 'Everyone', Decimal('28.47'), 738, 'present guy attention contain instead pressure behavior rather ask lawyer', 'interesting.gif', b'\x01')
# (136, 4, '4595092132730', 'Sure', Decimal('113.36'), 777, 'because when democrat back type lead time exactly feeling my', 'second.bmp', b'\x01')
# (137, 14, '5526360411355', 'Raise', Decimal('44.96'), 910, 'experience themselves certain once your collection too resource these per', 'state.gif', b'\x01')
# (138, 7, '4521675250430', 'Democrat', Decimal('316.14'), 347, 'ball use country reduce police peace second street difficult finally', 'some.gif', b'\x00')
# (139, 16, '4524793523806', 'Difference', Decimal('68.57'), 109, 'late senior author analysis forward arm glass pay let word', 'environmental.bmp', b'\x00')
# (140, 2, '5590992492006', 'Friend', Decimal('214.43'), 360, 'director participant tell thought here national guess compare drug size', 'himself.jpg', b'\x01')
# (141, 3, '4513325729663', 'Itself', Decimal('474.23'), 148, 'improve theory happen charge accept local certainly personal computer ability', 'three.tiff', b'\x00')
# (142, 22, '4544782518521', 'Carry', Decimal('486.59'), 227, 'blood ready director help near spend them role pressure suggest', 'skill.png', b'\x00')
# (143, 11, '4528879899632', 'Bank', Decimal('54.71'), 359, 'hour should power yet picture reflect final social respond pay', 'while.gif', b'\x01')
# (144, 2, '5596256558747', 'Pass', Decimal('83.48'), 442, 'expect animal could paper statement firm small by health attack', 'leave.tiff', b'\x01')
# (145, 15, '5513949995955', 'Music', Decimal('59.21'), 4, 'various bank side put now treatment glass century home together', 'box.gif', b'\x01')
# (146, 11, '4540996901807', 'Mention', Decimal('190.27'), 737, 'plan central future writer act former enter down machine note', 'end.jpg', b'\x00')
# (147, 13, '4556091069496', 'Challenge', Decimal('140.09'), 637, 'participant indeed three pass without sense guess visit catch professional', 'time.gif', b'\x01')
# (148, 16, '4542560497402', 'Though', Decimal('78.70'), 55, 'role send this center country to culture behavior generation individual', 'sort.jpeg', b'\x00')
# (149, 19, '4583066469777', 'Data', Decimal('160.21'), 350, 'song detail near culture thousand over thank ever involve black', 'difficult.bmp', b'\x00')
# (150, 6, '4523429131835', 'Where', Decimal('9.61'), 938, 'pull spring door himself role between former thought thought order', 'participant.tiff', b'\x00')
# (151, 21, '5564037389446', 'Conference', Decimal('427.87'), 576, 'enjoy throw respond those true might outside star account week', 'amount.jpg', b'\x00')
# (152, 2, '4597961911316', 'Never', Decimal('395.57'), 20, 'despite allow design design focus least too fill tell air', 'music.tiff', b'\x00')
# (153, 18, '4514947652070', 'Glass', Decimal('478.23'), 202, 'project discover fly boy suddenly artist look whole loss third', 'other.gif', b'\x00')
# (154, 22, '4561824879594', 'Newspaper', Decimal('238.57'), 582, 'dark budget possible authority skill smile each admit unit past', 'effect.tiff', b'\x00')
# (155, 6, '4595694126724', 'Laugh', Decimal('48.49'), 816, 'how popular thing true another because seek but true nice', 'car.jpg', b'\x01')
# (156, 10, '5574736570557', 'Without', Decimal('131.48'), 61, 'similar single maintain talk three season you send the too', 'policy.tiff', b'\x00')
# (157, 14, '4580298154389', 'Take', Decimal('451.21'), 76, 'serious material early three goal buy wide down address glass', 'generation.gif', b'\x00')
# (158, 15, '4520474871044', 'Experience', Decimal('437.46'), 259, 'write understand world sea morning moment every that figure also', 'during.jpeg', b'\x00')
# (159, 5, '5508883080577', 'Loss', Decimal('279.16'), 729, 'increase blue develop continue financial support focus recognize shoulder half', 'although.jpeg', b'\x01')
# (160, 12, '5582801807347', 'Wait', Decimal('404.18'), 289, 'simply three order early industry painting cost body amount factor', 'different.jpg', b'\x01')
# (161, 20, '4548934062894', 'Piece', Decimal('403.90'), 887, 'difficult almost threat capital majority eye or necessary work teacher', 'he.png', b'\x00')
# (162, 11, '4527062784885', 'Head', Decimal('23.87'), 903, 'study watch attention instead determine career appear how rock rock', 'agree.jpeg', b'\x01')
# (163, 9, '4567959050471', 'Yard', Decimal('371.70'), 550, 'visit door accept president music tax brother billion brother wife', 'attorney.jpeg', b'\x01')
# (164, 14, '4543524003301', 'Start', Decimal('388.21'), 494, 'concern arrive white various fall describe instead reduce country owner', 'no.bmp', b'\x00')
# (165, 6, '4593978440092', 'About', Decimal('362.36'), 25, 'speech music success approach child better season drive now from', 'simply.jpg', b'\x01')
# (166, 20, '5535079954503', 'Recent', Decimal('388.88'), 699, 'describe democratic through maintain standard rise own improve high later', 'consider.bmp', b'\x01')
# (167, 4, '4553009319384', 'Everything', Decimal('111.04'), 865, 'everything system wish development some few woman decade attorney source', 'painting.jpg', b'\x01')
# (168, 15, '5571772975490', 'Few', Decimal('417.47'), 497, 'operation child book respond own despite movement who environmental remain', 'wide.png', b'\x01')
# (169, 9, '5563499403882', 'Contain', Decimal('480.73'), 94, 'himself laugh record human human quickly together three sea appear', 'low.bmp', b'\x00')
# (170, 20, '4569688309400', 'Small', Decimal('187.77'), 689, 'your join spend must most amount poor push player fight', 'writer.tiff', b'\x01')
# (171, 14, '4543052862586', 'Professor', Decimal('328.15'), 598, 'situation small heart pattern here weight new amount better try', 'successful.gif', b'\x00')
# (172, 2, '5599141463706', 'Drug', Decimal('72.06'), 536, 'meeting land direction a new view total media morning ready', 'walk.jpg', b'\x01')
# (173, 21, '5533217752622', 'South', Decimal('268.04'), 450, 'skill trip church man past morning marriage whose when trial', 'bank.bmp', b'\x01')
# (174, 1, '5578157364139', 'Prove', Decimal('25.32'), 97, 'service one again end rather old hard price meeting woman', 'stage.jpg', b'\x01')
# (175, 12, '4573181144000', 'Commercial', Decimal('135.80'), 510, 'road staff like see skin close huge mean than national', 'become.png', b'\x00')
# (176, 15, '5528452966927', 'Organization', Decimal('205.76'), 203, 'born clear add then attention audience them mouth save edge', 'increase.jpg', b'\x01')
# (177, 15, '4521573364024', 'Position', Decimal('392.66'), 936, 'thus hundred drop light republican him sign six ground democratic', 'specific.bmp', b'\x01')
# (178, 15, '5504646169367', 'Market', Decimal('251.10'), 171, 'key study food since region professional truth voice hard here', 'professional.bmp', b'\x01')
# (179, 10, '4545918103239', 'Woman', Decimal('68.55'), 912, 'over two just no along fear finish suggest many tend', 'early.gif', b'\x00')
# (180, 10, '5556885464987', 'News', Decimal('246.53'), 584, 'development billion carry view store over mother kitchen common middle', 'gun.gif', b'\x01')
# (181, 21, '4510330254418', 'Me', Decimal('279.28'), 434, 'rise newspaper church reduce expect rather art lead available forget', 'plant.png', b'\x01')
# (182, 8, '5599868823975', 'Often', Decimal('477.89'), 715, 'avoid thing consumer trial law important agreement myself go every', 'sport.jpg', b'\x00')
# (183, 7, '4517881758389', 'Event', Decimal('268.79'), 999, 'give white feel claim reduce today follow billion everybody former', 'gas.jpg', b'\x01')
# (184, 1, '4577939201502', 'Serve', Decimal('268.97'), 390, 'they blue avoid over model from manage trip building style', 'partner.png', b'\x01')
# (185, 15, '4584072062815', 'Book', Decimal('311.26'), 937, 'level close author change around seek yeah partner son tell', 'center.jpeg', b'\x01')
# (186, 2, '4591118114889', 'Charge', Decimal('78.92'), 767, 'road end loss half should capital outside approach successful bar', 'role.jpeg', b'\x01')
# (187, 19, '4517223914077', 'However', Decimal('166.29'), 893, 'play machine line free total loss political cause federal remember', 'young.tiff', b'\x00')
# (188, 20, '4515895981007', 'Should', Decimal('183.01'), 645, 'six democrat will stay computer prepare cell produce sort red', 'speak.jpg', b'\x00')
# (189, 2, '4547477835101', 'Within', Decimal('74.00'), 708, 'already woman tonight military investment two pattern my out wall', 'national.bmp', b'\x00')
# (190, 18, '5552449388485', 'To', Decimal('442.51'), 94, 'time ok paper away you radio member head natural street', 'choice.bmp', b'\x01')
# (191, 19, '4542322734332', 'Tv', Decimal('394.02'), 326, 'almost accept single heavy human expect push make simply marriage', 'local.png', b'\x00')
# (192, 14, '5582534867403', 'Sit', Decimal('27.75'), 809, 'may discuss operation physical item together lawyer officer fact draw', 'market.jpg', b'\x00')
# (193, 5, '5567222536717', 'Early', Decimal('424.84'), 12, 'lead but left play miss market pm huge or thought', 'with.tiff', b'\x00')
# (194, 3, '4542770703478', 'Bar', Decimal('21.06'), 365, 'plan condition consumer stop image respond economic just suggest place', 'person.jpeg', b'\x01')
# (195, 16, '4525698922442', 'Investment', Decimal('397.17'), 330, 'mention wear arm team between cover daughter list last tax', 'house.jpeg', b'\x01')
# (196, 16, '4553215027981', 'Day', Decimal('486.83'), 372, 'his condition dark clearly degree interview culture shake sure control', 'perhaps.tiff', b'\x00')
# (197, 21, '4569474051735', 'Benefit', Decimal('221.53'), 18, 'property nearly certainly sound room control attack difference role speak', 'among.tiff', b'\x01')
# (198, 22, '4528663130590', 'Anything', Decimal('45.08'), 941, 'ball station business history tree reduce difference series son believe', 'several.bmp', b'\x01')
# (199, 16, '4548545393851', 'The', Decimal('264.49'), 538, 'budget road least throw maintain around by paper language indicate', 'such.png', b'\x00')
# (200, 20, '5524976179225', 'Learn', Decimal('108.68'), 386, 'early experience standard policy fish sister rule have approach choose', 'federal.jpeg', b'\x01')
#
# SELECT * FROM persona;
#
# (1, 'Supplier', 'Angela Burch', 'Passport', '460156818', '95704 Debra Mountains Apt. 129', '8479652109', 'millerrobert@example.net')
# (2, 'Supplier', 'Alison Carson', 'Passport', '671125254', '7912 Sherman Cove Apt. 887', '875-503-8766x61935', 'wilsonsarah@example.com')
# (3, 'Supplier', 'Connie Hull', 'DPI', '5403738945458', '44737 Becky Rapids Suite 375', '(945)622-7505x2953', 'benjamin17@example.org')
# (4, 'Supplier', 'Maureen Walters', 'Passport', 'P57638423', '84869 Dawn Mission', '+1-273-655-6646x6972', 'vtaylor@example.org')
# (5, 'Supplier', 'Joseph James', 'DPI', '8115752081379', '16230 Brandon Estates', '(716)646-4887x02092', 'kcarpenter@example.net')
# (6, 'Supplier', 'Daniel Kent', 'Passport', 'F42624135', '3148 Garrison Estate', '607-786-0164x9537', 'wilsonjames@example.org')
# (7, 'Supplier', 'Nicholas Boyd', 'DPI', '3532788060159', '636 Wiley Street', '290.339.7199x166', 'travisroberts@example.net')
# (8, 'Supplier', 'Heidi Torres', 'DPI', '3748689861173', '99356 Anthony Ports', '001-945-775-4256x844', 'danielle75@example.net')
# (9, 'Supplier', 'Jennifer Wilson', 'DPI', '901808047741', '4253 Bob Ferry', '+1-217-204-3187x6379', 'dwaynekidd@example.net')
# (10, 'Supplier', 'Michelle Bradley', 'Passport', 'D12586546', '6750 Dunn Roads Apt. 656', '714.981.7558', 'sabrina31@example.net')
# (11, 'Supplier', 'Brittney Alvarado', 'DPI', '5175866607009', '0273 Thomas Overpass Suite 928', '573.473.4275x5914', 'michael23@example.net')
# (12, 'Supplier', 'Matthew Galvan', 'Passport', 'Z37397494', '561 Barbara Wells Apt. 343', '+1-386-863-1830x4113', 'amy98@example.net')
# (13, 'Supplier', 'Timothy Mccoy', 'Passport', 'E07237102', '76749 Mary Roads Suite 802', '(365)869-1501x7394', 'smitheric@example.org')
# (14, 'Supplier', 'Lisa Mathis', 'DPI', '1866597654026', '3808 White Plain', '635.724.0368', 'brittanynorman@example.net')
# (15, 'Supplier', 'Andrew Powell', 'DPI', '2334998995807', '76429 Austin Cape', '508-991-0855', 'murillodavid@example.org')
# (16, 'Supplier', 'Dennis Lee', 'DPI', '5026707290637', '96892 Guzman Inlet', '637-595-4316', 'bgordon@example.net')
# (17, 'Supplier', 'Alexander Weaver', 'DPI', '7470219728581', '79211 Reynolds Ridges', '993.455.8980x447', 'ericstewart@example.org')
# (18, 'Supplier', 'Robert Johnson', 'Passport', 'Y15018105', '7428 Clay Well', '+1-544-460-4516x002', 'mhansen@example.org')
# (19, 'Supplier', 'Jeffrey Barry', 'Passport', '048316010', '8684 Ellis Shore', '001-878-923-0650x717', 'upitts@example.com')
# (20, 'Supplier', 'Ryan Day', 'Passport', '674331476', '5102 Donna Turnpike Suite 138', '+1-890-467-5147x523', 'reillyadam@example.org')
# (21, 'Supplier', 'Pamela Peterson', 'DPI', '8402960947590', '18387 Jermaine Mission Apt. 482', '(425)333-9456', 'andrewadams@example.org')
# (22, 'Supplier', 'Crystal Jimenez', 'Passport', '213100744', '5035 Angela Gardens Apt. 377', '(847)851-5930x706', 'loganmatthews@example.com')
# (23, 'Supplier', 'Courtney Prince', 'DPI', '7011564764883', '63203 Steven Squares Suite 409', '525.891.2735x739', 'ianrusso@example.net')
# (24, 'Supplier', 'Brittany Sheppard', 'Passport', '697393608', '35200 Hill Canyon', '001-646-391-3172x391', 'aaron68@example.com')
# (25, 'Supplier', 'Brooke Parker', 'DPI', '1532159929547', '2604 Holden Stravenue', '+1-644-333-1833x7896', 'mayerdawn@example.org')
# (26, 'Supplier', 'Scott Woods', 'DPI', '186946050323', '32920 Vanessa Dam Apt. 317', '229.960.4235x179', 'jenniferlin@example.org')
# (27, 'Supplier', 'Michael Gonzales', 'DPI', '3752601010356', '101 Daniel Alley Apt. 591', '614.530.9961x18483', 'marymcintyre@example.org')
# (28, 'Supplier', 'Melanie Mason', 'DPI', '1519319779857', '944 Maria Key', '001-518-580-6880x411', 'michael40@example.net')
# (29, 'Supplier', 'Emily Carter', 'DPI', '5260828513756', '687 Williams Rapid', '001-269-662-1829x745', 'laura53@example.com')
# (30, 'Supplier', 'Kathryn Wu', 'Passport', '781373395', '762 Ronald Isle', '001-836-509-7225x462', 'riddlejody@example.net')
# (31, 'Supplier', 'Larry Espinoza', 'DPI', '4418648939257', '6237 Jones Keys Apt. 520', '001-327-940-7055x974', 'gentryrobert@example.net')
# (32, 'Supplier', 'Sherry Smith', 'DPI', '5835301158987', '43319 Ramos Route', '+1-376-787-9290x6170', 'nmarshall@example.com')
# (33, 'Supplier', 'Zachary Sherman', 'DPI', '3411280980343', '1440 Lisa Villages', '+1-262-810-7174', 'karen10@example.com')
# (34, 'Supplier', 'Margaret Robinson', 'DPI', '4514535591339', '6351 White Rest Suite 171', '(423)524-0405', 'meyerdaniel@example.com')
# (35, 'Supplier', 'Paige Young', 'DPI', '5022107486540', '58447 Micheal Gateway', '+1-599-490-0815x088', 'oliverkelly@example.org')
# (36, 'Supplier', 'Jennifer Gutierrez', 'DPI', '7590943304165', '589 Kathy Spring', '2553185616', 'matthew13@example.org')
# (37, 'Supplier', 'Ann Thomas', 'DPI', '4039571882330', '958 Heidi Ports Suite 755', '001-440-630-0760x502', 'othomas@example.org')
# (38, 'Supplier', 'Victoria Norris MD', 'DPI', '8006318559778', '8310 Gina Wells', '352-257-6148', 'michelle37@example.com')
# (39, 'Supplier', 'Christina Knight', 'Passport', 'I25084880', '83183 Sean Ways', '+1-262-208-1539x7700', 'jacksonkatherine@example.net')
# (40, 'Supplier', 'Christopher Hubbard', 'Passport', '296983364', '25260 Robert Mountain Apt. 360', '3503979804', 'toni87@example.org')
# (41, 'Supplier', 'Diane Nunez', 'DPI', '2891811518404', '7549 Jesse Plaza', '754.236.0207x6504', 'clloyd@example.com')
# (42, 'Supplier', 'Kimberly Castro', 'DPI', '3735549928523', '272 Valerie Mission Suite 520', '+1-479-261-6354', 'mccartycynthia@example.com')
# (43, 'Supplier', 'Matthew Johnson', 'DPI', '202538160961', '3670 Davenport Motorway', '(855)217-4340x5310', 'jeremy89@example.com')
# (44, 'Supplier', 'Amanda Moss', 'Passport', 'I62911121', '61244 Michael Fields Apt. 889', '666-670-0948', 'deborahthomas@example.org')
# (45, 'Supplier', 'Shelly Gibson DVM', 'DPI', '9435822806131', '2880 Cox Locks Suite 652', '769.628.4718', 'brooke36@example.com')
# (46, 'Supplier', 'Catherine Martin', 'DPI', '2077151889812', '5352 Ashlee Mission Apt. 386', '903.888.7143x234', 'dixonhannah@example.org')
# (47, 'Supplier', 'Joseph Cain', 'Passport', 'I21701441', '91455 Ashley Glens Suite 120', '(274)212-8611x245', 'andrehood@example.net')
# (48, 'Supplier', 'Vanessa Glenn', 'DPI', '436811109857', '4519 Michael Cliffs', '+1-742-312-8242x9245', 'ricardo63@example.net')
# (49, 'Supplier', 'Jacob Washington', 'Passport', 'U90852802', '224 Frazier Ford Apt. 665', '721.216.0963x091', 'jasmineatkinson@example.org')
# (50, 'Supplier', 'Brian Holmes', 'DPI', '9394154995452', '3408 Jennings Meadow Apt. 075', '2427060214', 'kennethbrown@example.org')
# (51, 'Supplier', 'Joshua Robinson', 'Passport', 'T95524048', '2723 Tony Manors', '454-352-8129x847', 'ewalker@example.org')
# (52, 'Supplier', 'Rachel Chavez', 'Passport', 'I89539580', '980 Ariel Walk Apt. 345', '6306472080', 'cwhite@example.com')
# (53, 'Supplier', 'Karina Pena', 'DPI', '4400185518279', '10909 Pena Pike Apt. 194', '+1-523-350-7346', 'conleytroy@example.org')
# (54, 'Supplier', 'Miss Pamela Gordon', 'Passport', 'U17407192', '85937 Williams Dale Apt. 601', '807.761.8057x53669', 'nicole14@example.com')
# (55, 'Supplier', 'Andrew Roberts', 'Passport', '956231218', '60767 Molly Divide', '001-712-793-8855x397', 'lgonzalez@example.com')
# (56, 'Supplier', 'Lisa Padilla', 'DPI', '2504190886000', '971 Lawrence Forges', '472.708.3509', 'cruzjoseph@example.net')
# (57, 'Supplier', 'Abigail Rodriguez', 'Passport', 'K51881893', '2233 Kristen Run Apt. 001', '+1-366-371-6171x7184', 'nathan13@example.org')
# (58, 'Supplier', 'Mr. Donald Williams', 'DPI', '3240174273869', '510 Dominguez Street', '261-342-4530', 'troy98@example.net')
# (59, 'Supplier', 'Robert Tanner', 'Passport', '416412768', '69075 Ruben Harbors', '286.807.8121x0637', 'joditucker@example.net')
# (60, 'Supplier', 'Danielle Powell', 'Passport', '936486071', '9261 Austin Squares', '(784)218-6433', 'yrandall@example.net')
# (61, 'Supplier', 'Rita Sandoval', 'Passport', 'Z12194318', '369 John Drive', '+1-867-465-3107x9674', 'nmartin@example.org')
# (62, 'Supplier', 'Michael Hobbs', 'Passport', 'P21249459', '5399 Lewis Drives', '+1-454-910-4159x926', 'nelsonamanda@example.net')
# (63, 'Supplier', 'Sara Torres', 'Passport', '525819143', '017 Rebecca Mountain', '4532644875', 'ambergarcia@example.net')
# (64, 'Supplier', 'Brent Bryant', 'DPI', '6193338384928', '451 Brennan Stream Suite 344', '+1-978-679-6910x0345', 'chowe@example.org')
# (65, 'Supplier', 'David Baldwin', 'DPI', '2557139490981', '78676 Herrera Meadow', '872-462-1634', 'cwalker@example.net')
# (66, 'Supplier', 'Jeffrey Jordan', 'DPI', '6808203778072', '445 Washington Locks', '725.893.1859x391', 'brooke07@example.net')
# (67, 'Supplier', 'Mr. Keith Miller II', 'DPI', '6888546795049', '00723 Katherine Haven Apt. 513', '333.994.0751x53493', 'kimberly97@example.com')
# (68, 'Supplier', 'Jordan Rogers', 'Passport', '230703039', '28161 Phillip Trafficway', '001-448-210-2076x978', 'harperelizabeth@example.org')
# (69, 'Supplier', 'Maria Ross', 'DPI', '1815029922591', '35467 Peterson Village', '592.661.4514x213', 'mwagner@example.org')
# (70, 'Supplier', 'April Russell', 'Passport', 'C18983320', '5907 Kevin Harbor Suite 347', '(627)470-6473', 'ortizomar@example.org')
# (71, 'Supplier', 'Lisa Vasquez', 'Passport', 'I97678640', '81040 Snyder Ports Apt. 128', '972.492.6984', 'linda14@example.net')
# (72, 'Supplier', 'Tyler Ward II', 'Passport', 'Y89672944', '158 Amy Lodge Suite 290', '+1-595-655-9723x2558', 'jacob37@example.net')
# (73, 'Supplier', 'Carol Smith', 'Passport', 'Q62997629', '5616 Sanchez Underpass Apt. 282', '(966)690-1060x551', 'abrown@example.org')
# (74, 'Supplier', 'Jennifer Coleman', 'DPI', '5364346547021', '836 Murphy Mews Suite 732', '(614)390-7925', 'kenneth48@example.net')
# (75, 'Supplier', 'Kayla Riley', 'DPI', '1897303570719', '342 Edward Garden', '500.677.1517x4919', 'tanneramber@example.com')
# (76, 'Supplier', 'Sarah Davis', 'Passport', 'Z88678609', '4439 Todd Creek Apt. 927', '001-609-383-1159x690', 'timothyjones@example.net')
# (77, 'Supplier', 'Tara Caldwell', 'Passport', '815438965', '3313 Huang Extension Suite 345', '807-303-6698', 'randolphmichael@example.org')
# (78, 'Supplier', 'Lauren Russell', 'DPI', '2218692207235', '2504 Maldonado Ferry Suite 388', '611.310.5914x86301', 'scottcantu@example.org')
# (79, 'Supplier', 'Brandon Lynch', 'DPI', '6195066757824', '051 Nicholas Highway', '001-631-897-3067x814', 'suttoncheryl@example.com')
# (80, 'Supplier', 'Karen Walker', 'Passport', '918939876', '5876 Jay Pike Apt. 497', '699.868.8058', 'prodriguez@example.com')
# (81, 'Supplier', 'Kenneth Jones', 'Passport', 'X73434107', '804 Ortiz Pine Suite 387', '(382)748-3727', 'davistodd@example.com')
# (82, 'Supplier', 'Cynthia Shields', 'DPI', '3356862213741', '5192 Williams Manors Apt. 012', '4035237891', 'uspencer@example.com')
# (83, 'Supplier', 'Carolyn Green', 'Passport', 'I48053349', '13248 Anthony Trafficway', '(615)553-9645x516', 'paul65@example.net')
# (84, 'Supplier', 'Lisa Ferguson MD', 'Passport', '130853023', '36536 Jones Meadows Apt. 611', '6574689640', 'lopezsharon@example.org')
# (85, 'Supplier', 'Katelyn Hubbard', 'DPI', '8264297961004', '6367 Carol Dam', '935.951.7573x7782', 'jharvey@example.org')
# (86, 'Supplier', 'Joshua Brown', 'DPI', '7897970434026', '784 Thomas Rue', '401-227-1010', 'jeffreyfrazier@example.com')
# (87, 'Supplier', 'Lauren Jackson', 'DPI', '584639995347', '45331 Dickson Spring', '(619)523-8613', 'rachel63@example.org')
# (88, 'Supplier', 'Heather Fernandez', 'DPI', '869190546039', '826 Jennifer Trace', '3579471017', 'frank82@example.org')
# (89, 'Supplier', 'Mrs. Michelle Galloway', 'DPI', '3791082633533', '79031 Payne Squares Suite 391', '+1-219-854-3271x775', 'adkinsnancy@example.net')
# (90, 'Supplier', 'Danielle Rogers', 'Passport', 'G03798181', '00482 Fleming Road', '001-930-252-0627x859', 'ramirezmark@example.org')
# (91, 'Supplier', 'James Barker', 'DPI', '5412817540829', '4511 Jaclyn Greens', '4375622867', 'wyattcheryl@example.com')
# (92, 'Supplier', 'James Williams', 'DPI', '5985305787465', '36130 Graves Turnpike', '(463)641-4574x365', 'ztaylor@example.org')
# (93, 'Supplier', 'Bradley Hodge', 'Passport', '448754248', '597 Valdez Mews Apt. 070', '001-429-215-7097x829', 'lindapena@example.com')
# (94, 'Supplier', 'Rhonda Harris', 'Passport', 'A00899410', '072 Ryan Turnpike', '+1-844-355-9499x037', 'rreynolds@example.org')
# (95, 'Supplier', 'Matthew Rivera', 'DPI', '5340443941155', '813 Robert Shores Apt. 211', '4042382229', 'jason75@example.org')
# (96, 'Supplier', 'Daniel Braun', 'Passport', '788075304', '2240 Dennis Manor', '369.370.6277x6604', 'combsheather@example.net')
# (97, 'Supplier', 'Joshua Keith', 'DPI', '5367074436756', '985 Jackson Knoll Suite 273', '218-685-5075', 'davilasean@example.org')
# (98, 'Supplier', 'Pamela Green', 'DPI', '9604264199811', '738 Kristy Trail Suite 758', '001-744-952-5565x617', 'peterholmes@example.org')
# (99, 'Supplier', 'Tyler Rivera', 'DPI', '4737760098546', '3853 Morton Forges Suite 843', '528-865-6674', 'chankristi@example.org')
# (100, 'Supplier', 'Ricardo Navarro', 'Passport', 'J18871118', '0339 Jennifer Walk Apt. 678', '+1-464-461-4310x5416', 'duanewhite@example.net')
# (101, 'Client', 'Raymond Sanchez', 'DPI', '110092910081', '41682 Meza Route', '827.265.2776x109', 'sraymond@example.net')
# (102, 'Client', 'Jennifer Meadows DDS', 'DPI', '5827467274355', '036 Alyssa Pines Suite 058', '001-294-385-5735x120', 'jerrylyons@example.com')
# (103, 'Client', 'Patrick Banks', 'DPI', '4803093240416', '9815 York Curve', '862-619-2725x4691', 'andrew15@example.com')
# (104, 'Client', 'Joel Allen', 'Passport', 'K43692028', '8922 Christina Walk', '6712502116', 'bradley96@example.com')
# (105, 'Client', 'Joseph Robertson', 'DPI', '6550147611613', '41607 Daniel Drives', '+1-206-306-2100', 'khuynh@example.com')
# (106, 'Client', 'Kathleen Hayden', 'Passport', '323880219', '36904 King Plaza Suite 339', '001-202-881-0277', 'kevans@example.net')
# (107, 'Client', 'Justin Green', 'DPI', '9733201726747', '9692 Barbara Alley Apt. 145', '276-835-8863x5449', 'zanderson@example.org')
# (108, 'Client', 'Peggy Soto', 'Passport', 'Y73654568', '293 Wilson Orchard', '001-968-472-5435x873', 'robertkramer@example.com')
# (109, 'Client', 'Angela Miller', 'Passport', '469850083', '20299 Diana Lane', '(659)246-2143x1843', 'tylermontgomery@example.com')
# (110, 'Client', 'Gina Anderson', 'Passport', '837039281', '53100 Andrew Motorway', '(570)521-9424x78541', 'kristophersaunders@example.org')
# (111, 'Client', 'Krystal Whitehead', 'DPI', '2960854466948', '65586 Joseph Ferry Suite 994', '2135740905', 'longstephanie@example.net')
# (112, 'Client', 'Jeremy Solomon DVM', 'Passport', '407936745', '6332 Lisa Expressway', '(435)413-0728x094', 'dawsonrandy@example.com')
# (113, 'Client', 'Brandon Kelly', 'Passport', 'L90094798', '077 Brown Park Suite 742', '(366)365-5493', 'nhernandez@example.net')
# (114, 'Client', 'Emily Atkinson', 'Passport', '986403271', '8963 Kristy Crest', '(460)973-5401', 'batesarthur@example.net')
# (115, 'Client', 'Joseph Bowers', 'Passport', 'R96294159', '5386 Mata Shoals', '398-696-7224x46394', 'huffmisty@example.com')
# (116, 'Client', 'Alison Diaz', 'DPI', '1622909767606', '5240 Aaron Lock Apt. 381', '(731)855-8582', 'karen83@example.com')
# (117, 'Client', 'Shannon Norris', 'DPI', '8455102199879', '3662 Tate Stream Apt. 809', '232-806-0112x58027', 'kkramer@example.com')
# (118, 'Client', 'Stephen Edwards', 'Passport', 'G21321579', '921 Watson Spur Apt. 119', '+1-993-743-2039x448', 'darlenesims@example.net')
# (119, 'Client', 'Tina Wiggins', 'Passport', 'Z47448271', '1177 Carpenter Mountain', '790.986.8890x19184', 'shawntrujillo@example.org')
# ...
# (9822, 43, 276, 5, Decimal('459.93'), Decimal('63.50'))
# (9823, 763, 156, 4, Decimal('577.84'), Decimal('56.59'))
# (9824, 137, 230, 2, Decimal('720.27'), Decimal('153.99'))
# (9825, 301, 15, 3, Decimal('317.04'), Decimal('43.70'))
# (9826, 209, 283, 2, Decimal('290.64'), Decimal('42.27'))
# (9827, 44, 126, 6, Decimal('581.60'), Decimal('64.80'))
# (9828, 868, 36, 10, Decimal('383.49'), Decimal('93.22'))
# (9829, 844, 245, 7, Decimal('466.99'), Decimal('66.89'))
# (9830, 730, 128, 10, Decimal('248.87'), Decimal('54.26'))
# (9831, 303, 91, 1, Decimal('243.44'), Decimal('13.11'))
# (9832, 508, 243, 8, Decimal('22.66'), Decimal('5.64'))
# (9833, 49, 1, 8, Decimal('651.12'), Decimal('52.06'))
# (9834, 994, 62, 2, Decimal('268.14'), Decimal('53.18'))
# (9835, 939, 128, 6, Decimal('291.69'), Decimal('46.90'))
# (9836, 676, 109, 7, Decimal('511.56'), Decimal('95.14'))
# (9837, 772, 9, 7, Decimal('727.63'), Decimal('79.66'))
# (9838, 745, 173, 4, Decimal('218.97'), Decimal('49.77'))
# (9839, 495, 47, 10, Decimal('73.05'), Decimal('6.96'))
# (9840, 443, 225, 4, Decimal('233.00'), Decimal('32.40'))
# (9841, 116, 63, 1, Decimal('454.32'), Decimal('37.43'))
# (9842, 746, 86, 7, Decimal('528.43'), Decimal('55.91'))
# (9843, 29, 253, 6, Decimal('87.33'), Decimal('12.66'))
# (9844, 576, 47, 8, Decimal('252.07'), Decimal('55.43'))
# (9845, 188, 225, 2, Decimal('351.58'), Decimal('41.25'))
# (9846, 375, 32, 2, Decimal('208.88'), Decimal('30.69'))
# (9847, 349, 181, 4, Decimal('49.92'), Decimal('5.75'))
# (9848, 70, 256, 1, Decimal('271.07'), Decimal('58.60'))
# (9849, 101, 246, 10, Decimal('695.63'), Decimal('53.61'))
# (9850, 286, 259, 8, Decimal('610.90'), Decimal('122.92'))
# (9851, 914, 43, 4, Decimal('708.91'), Decimal('81.82'))
# (9852, 299, 36, 8, Decimal('745.74'), Decimal('90.75'))
# (9853, 11, 173, 7, Decimal('137.39'), Decimal('31.68'))
# (9854, 444, 26, 9, Decimal('628.10'), Decimal('113.11'))
# (9855, 135, 250, 4, Decimal('115.27'), Decimal('13.86'))
# (9856, 414, 262, 9, Decimal('353.55'), Decimal('48.70'))
# (9857, 932, 279, 2, Decimal('497.35'), Decimal('102.23'))
# (9858, 438, 135, 5, Decimal('397.04'), Decimal('75.22'))
# (9859, 623, 22, 10, Decimal('723.88'), Decimal('110.15'))
# (9860, 902, 157, 9, Decimal('697.24'), Decimal('162.66'))
# (9861, 967, 279, 10, Decimal('215.42'), Decimal('24.20'))
# (9862, 743, 169, 6, Decimal('87.96'), Decimal('8.28'))
# (9863, 546, 15, 8, Decimal('708.29'), Decimal('101.84'))
# (9864, 838, 134, 2, Decimal('317.58'), Decimal('77.59'))
# (9865, 778, 140, 8, Decimal('732.46'), Decimal('142.85'))
# (9866, 547, 134, 1, Decimal('596.27'), Decimal('129.25'))
# (9867, 173, 4, 6, Decimal('341.78'), Decimal('25.26'))
# (9868, 475, 33, 9, Decimal('61.30'), Decimal('13.09'))
# (9869, 956, 10, 1, Decimal('536.41'), Decimal('40.39'))
# (9870, 600, 270, 3, Decimal('361.33'), Decimal('58.70'))
# (9871, 683, 145, 6, Decimal('620.88'), Decimal('139.80'))
# (9872, 369, 257, 4, Decimal('105.35'), Decimal('11.25'))
# (9873, 538, 21, 8, Decimal('166.32'), Decimal('29.68'))
# (9874, 203, 172, 9, Decimal('409.44'), Decimal('57.60'))
# (9875, 346, 6, 10, Decimal('120.79'), Decimal('27.29'))
# (9876, 763, 289, 2, Decimal('40.45'), Decimal('8.58'))
# (9877, 662, 182, 3, Decimal('413.99'), Decimal('22.48'))
# (9878, 169, 188, 6, Decimal('712.48'), Decimal('163.26'))
# (9879, 167, 157, 7, Decimal('597.84'), Decimal('74.70'))
# (9880, 536, 37, 2, Decimal('300.14'), Decimal('57.05'))
# (9881, 758, 72, 10, Decimal('518.77'), Decimal('122.95'))
# (9882, 540, 65, 4, Decimal('606.56'), Decimal('39.95'))
# (9883, 55, 93, 7, Decimal('318.24'), Decimal('40.76'))
# (9884, 52, 132, 4, Decimal('267.63'), Decimal('57.20'))
# (9885, 355, 241, 1, Decimal('664.64'), Decimal('85.26'))
# (9886, 144, 115, 1, Decimal('629.15'), Decimal('107.63'))
# (9887, 405, 179, 7, Decimal('683.15'), Decimal('145.32'))
# (9888, 892, 264, 2, Decimal('371.89'), Decimal('92.26'))
# (9889, 785, 176, 2, Decimal('546.97'), Decimal('105.96'))
# (9890, 754, 210, 10, Decimal('137.45'), Decimal('13.94'))
# (9891, 842, 138, 8, Decimal('407.87'), Decimal('95.40'))
# (9892, 315, 35, 8, Decimal('406.64'), Decimal('96.26'))
# (9893, 987, 22, 7, Decimal('492.69'), Decimal('118.68'))
# (9894, 785, 107, 10, Decimal('748.42'), Decimal('91.90'))
# (9895, 34, 74, 7, Decimal('286.57'), Decimal('36.70'))
# (9896, 28, 289, 4, Decimal('250.38'), Decimal('44.82'))
# (9897, 640, 180, 2, Decimal('539.44'), Decimal('36.04'))
# (9898, 541, 169, 8, Decimal('174.99'), Decimal('20.28'))
# (9899, 862, 226, 2, Decimal('228.06'), Decimal('44.79'))
# (9900, 349, 251, 10, Decimal('424.11'), Decimal('42.26'))
# (9901, 638, 96, 6, Decimal('690.92'), Decimal('168.12'))
# (9902, 488, 253, 9, Decimal('550.91'), Decimal('76.43'))
# (9903, 448, 297, 7, Decimal('81.35'), Decimal('4.37'))
# (9904, 903, 220, 10, Decimal('472.49'), Decimal('116.43'))
# (9905, 316, 99, 9, Decimal('403.20'), Decimal('53.64'))
# (9906, 667, 255, 3, Decimal('559.58'), Decimal('139.51'))
# (9907, 183, 285, 9, Decimal('137.57'), Decimal('26.63'))
# (9908, 552, 49, 7, Decimal('575.92'), Decimal('117.41'))
# (9909, 662, 120, 7, Decimal('448.09'), Decimal('102.64'))
# (9910, 943, 63, 2, Decimal('381.48'), Decimal('45.64'))
# (9911, 738, 50, 9, Decimal('129.96'), Decimal('20.51'))
# (9912, 901, 42, 1, Decimal('371.54'), Decimal('43.55'))
# (9913, 423, 209, 2, Decimal('728.02'), Decimal('115.52'))
# (9914, 58, 2, 10, Decimal('579.83'), Decimal('78.90'))
# (9915, 23, 44, 4, Decimal('245.44'), Decimal('25.76'))
# (9916, 405, 284, 7, Decimal('658.92'), Decimal('158.69'))
# (9917, 79, 210, 6, Decimal('45.53'), Decimal('10.88'))
# (9918, 74, 205, 7, Decimal('62.09'), Decimal('14.52'))
# (9919, 239, 259, 10, Decimal('554.34'), Decimal('97.60'))
# (9920, 794, 160, 10, Decimal('358.40'), Decimal('83.86'))
# (9921, 44, 95, 1, Decimal('8.81'), Decimal('1.57'))
# (9922, 836, 278, 7, Decimal('604.05'), Decimal('79.60'))
# (9923, 772, 51, 10, Decimal('723.83'), Decimal('88.19'))
# (9924, 530, 3, 7, Decimal('537.23'), Decimal('104.14'))
# (9925, 367, 284, 5, Decimal('507.92'), Decimal('76.25'))
# (9926, 193, 172, 4, Decimal('620.71'), Decimal('90.60'))
# (9927, 601, 8, 3, Decimal('280.09'), Decimal('62.84'))
# (9928, 553, 243, 5, Decimal('150.14'), Decimal('34.31'))
# (9929, 643, 144, 6, Decimal('366.91'), Decimal('25.07'))
# (9930, 391, 50, 6, Decimal('579.50'), Decimal('42.70'))
# (9931, 515, 256, 4, Decimal('643.93'), Decimal('86.75'))
# (9932, 886, 234, 2, Decimal('81.78'), Decimal('4.66'))
# (9933, 898, 147, 3, Decimal('280.51'), Decimal('35.63'))
# (9934, 739, 295, 6, Decimal('377.08'), Decimal('50.66'))
# (9935, 45, 287, 2, Decimal('635.12'), Decimal('54.27'))
# (9936, 14, 10, 4, Decimal('175.25'), Decimal('24.10'))
# (9937, 482, 270, 6, Decimal('362.57'), Decimal('80.37'))
# (9938, 967, 212, 2, Decimal('11.44'), Decimal('2.06'))
# (9939, 484, 286, 9, Decimal('98.58'), Decimal('14.75'))
# (9940, 941, 128, 9, Decimal('337.97'), Decimal('34.06'))
# (9941, 221, 172, 4, Decimal('661.44'), Decimal('80.93'))
# (9942, 89, 284, 2, Decimal('649.98'), Decimal('53.72'))
# (9943, 25, 10, 3, Decimal('423.35'), Decimal('90.89'))
# (9944, 693, 141, 7, Decimal('164.19'), Decimal('15.97'))
# (9945, 772, 84, 4, Decimal('617.48'), Decimal('36.33'))
# (9946, 620, 266, 2, Decimal('194.17'), Decimal('45.84'))
# (9947, 721, 287, 5, Decimal('737.83'), Decimal('54.13'))
# (9948, 254, 289, 9, Decimal('343.63'), Decimal('66.02'))
# (9949, 189, 98, 1, Decimal('523.43'), Decimal('121.37'))
# (9950, 206, 86, 4, Decimal('660.25'), Decimal('159.53'))
# (9951, 569, 23, 7, Decimal('470.98'), Decimal('108.31'))
# (9952, 610, 277, 2, Decimal('22.52'), Decimal('2.44'))
# (9953, 448, 82, 3, Decimal('600.02'), Decimal('70.80'))
# (9954, 131, 193, 8, Decimal('273.51'), Decimal('13.76'))
# (9955, 807, 179, 2, Decimal('738.61'), Decimal('47.11'))
# (9956, 686, 85, 6, Decimal('73.40'), Decimal('13.66'))
# (9957, 226, 44, 4, Decimal('338.19'), Decimal('41.48'))
# (9958, 408, 69, 9, Decimal('450.14'), Decimal('64.76'))
# (9959, 115, 153, 5, Decimal('355.01'), Decimal('56.59'))
# (9960, 20, 221, 7, Decimal('159.87'), Decimal('32.23'))
# (9961, 996, 95, 2, Decimal('597.12'), Decimal('145.48'))
# (9962, 27, 4, 4, Decimal('232.47'), Decimal('26.88'))
# (9963, 118, 218, 8, Decimal('669.22'), Decimal('54.50'))
# (9964, 102, 285, 8, Decimal('7.20'), Decimal('1.20'))
# (9965, 244, 215, 8, Decimal('308.51'), Decimal('62.84'))
# (9966, 249, 178, 4, Decimal('50.43'), Decimal('9.53'))
# (9967, 98, 142, 5, Decimal('355.51'), Decimal('22.00'))
# (9968, 702, 119, 1, Decimal('606.51'), Decimal('120.73'))
# (9969, 927, 11, 1, Decimal('507.22'), Decimal('125.37'))
# (9970, 464, 23, 2, Decimal('651.44'), Decimal('124.78'))
# (9971, 837, 202, 8, Decimal('441.71'), Decimal('100.38'))
# (9972, 105, 201, 10, Decimal('661.17'), Decimal('36.45'))
# (9973, 558, 78, 3, Decimal('310.94'), Decimal('43.22'))
# (9974, 133, 86, 8, Decimal('506.27'), Decimal('104.39'))
# (9975, 463, 53, 4, Decimal('736.43'), Decimal('126.58'))
# (9976, 389, 133, 5, Decimal('179.01'), Decimal('31.13'))
# (9977, 65, 232, 8, Decimal('287.46'), Decimal('14.61'))
# (9978, 184, 50, 6, Decimal('194.95'), Decimal('46.24'))
# (9979, 851, 110, 10, Decimal('615.23'), Decimal('89.20'))
# (9980, 412, 72, 2, Decimal('93.15'), Decimal('12.15'))
# (9981, 986, 278, 8, Decimal('383.29'), Decimal('42.09'))
# (9982, 427, 159, 5, Decimal('240.07'), Decimal('40.98'))
# (9983, 485, 64, 3, Decimal('226.37'), Decimal('24.63'))
# (9984, 397, 160, 2, Decimal('77.31'), Decimal('12.80'))
# (9985, 632, 74, 8, Decimal('627.80'), Decimal('66.89'))
# (9986, 472, 46, 1, Decimal('292.99'), Decimal('30.86'))
# (9987, 289, 63, 2, Decimal('441.43'), Decimal('64.61'))
# (9988, 299, 58, 2, Decimal('123.09'), Decimal('17.36'))
# (9989, 748, 297, 5, Decimal('568.51'), Decimal('42.17'))
# (9990, 47, 229, 4, Decimal('476.86'), Decimal('43.96'))
# (9991, 184, 145, 8, Decimal('625.59'), Decimal('79.68'))
# (9992, 190, 203, 5, Decimal('19.15'), Decimal('2.16'))
# (9993, 749, 86, 2, Decimal('341.77'), Decimal('53.16'))
# (9994, 794, 64, 6, Decimal('585.41'), Decimal('47.33'))
# (9995, 701, 190, 8, Decimal('706.74'), Decimal('167.11'))
# (9996, 9, 111, 8, Decimal('504.38'), Decimal('118.09'))
# (9997, 741, 255, 5, Decimal('549.10'), Decimal('95.30'))
# (9998, 696, 208, 8, Decimal('397.27'), Decimal('76.07'))
# (9999, 681, 194, 10, Decimal('49.63'), Decimal('9.32'))
# (10000, 379, 245, 3, Decimal('559.37'), Decimal('35.43'))
#
# SELECT * FROM detalle_ingreso;
#
# (1, 132, 183, 1138, Decimal('258.01'))
# (2, 108, 192, 568, Decimal('396.15'))
# (3, 52, 105, 248, Decimal('281.75'))
# (4, 52, 193, 1331, Decimal('917.01'))
# (5, 141, 102, 866, Decimal('760.74'))
# (6, 99, 25, 961, Decimal('447.47'))
# (7, 9, 166, 584, Decimal('573.27'))
# (8, 39, 153, 1264, Decimal('553.37'))
# (9, 135, 293, 1517, Decimal('434.59'))
# (10, 72, 135, 532, Decimal('552.94'))
# (11, 32, 11, 1849, Decimal('61.77'))
# (12, 2, 91, 1954, Decimal('514.27'))
# (13, 94, 175, 1304, Decimal('186.79'))
# (14, 116, 132, 219, Decimal('663.05'))
# (15, 109, 137, 1849, Decimal('421.68'))
# (16, 9, 29, 486, Decimal('346.88'))
# (17, 68, 283, 511, Decimal('806.34'))
# (18, 134, 94, 31, Decimal('252.81'))
# (19, 43, 35, 402, Decimal('445.10'))
# (20, 59, 241, 657, Decimal('495.60'))
# (21, 91, 264, 761, Decimal('512.50'))
# (22, 29, 170, 451, Decimal('926.84'))
# (23, 129, 91, 625, Decimal('981.54'))
# (24, 71, 199, 1094, Decimal('964.52'))
# (25, 44, 278, 1856, Decimal('872.45'))
# (26, 132, 238, 1916, Decimal('30.24'))
# (27, 116, 26, 1318, Decimal('257.35'))
# (28, 92, 32, 1346, Decimal('929.88'))
# (29, 84, 25, 1786, Decimal('421.17'))
# (30, 88, 36, 1426, Decimal('814.38'))
# (31, 125, 38, 922, Decimal('830.92'))
# (32, 82, 245, 706, Decimal('148.92'))
# (33, 6, 22, 1048, Decimal('193.09'))
# (34, 130, 275, 1942, Decimal('87.63'))
# (35, 18, 103, 1968, Decimal('869.13'))
# (36, 73, 278, 1390, Decimal('149.26'))
# (37, 80, 90, 1834, Decimal('770.80'))
# (38, 120, 142, 1479, Decimal('274.74'))
# (39, 28, 12, 323, Decimal('284.24'))
# (40, 101, 147, 1398, Decimal('36.12'))
# (41, 11, 210, 687, Decimal('329.80'))
# (42, 34, 19, 934, Decimal('202.13'))
# (43, 89, 69, 1132, Decimal('187.69'))
# (44, 34, 299, 1769, Decimal('582.97'))
# (45, 24, 208, 1, Decimal('827.15'))
# (46, 51, 133, 987, Decimal('378.93'))
# (47, 95, 61, 260, Decimal('677.17'))
# (48, 102, 72, 715, Decimal('844.96'))
# (49, 71, 241, 24, Decimal('553.51'))
# (50, 31, 34, 1909, Decimal('388.49'))
# (51, 116, 124, 1874, Decimal('914.96'))
# (52, 99, 56, 935, Decimal('439.29'))
# (53, 69, 172, 1376, Decimal('658.39'))
# (54, 119, 152, 1017, Decimal('744.18'))
# (55, 45, 85, 965, Decimal('139.36'))
# (56, 116, 232, 1155, Decimal('592.60'))
# (57, 6, 189, 1784, Decimal('799.57'))
# (58, 120, 185, 1024, Decimal('904.27'))
# (59, 28, 175, 1428, Decimal('494.83'))
# (60, 26, 214, 693, Decimal('621.71'))
# (61, 1, 272, 1709, Decimal('814.03'))
# (62, 94, 235, 351, Decimal('67.34'))
# (63, 78, 283, 1777, Decimal('767.25'))
# (64, 21, 208, 96, Decimal('634.79'))
# (65, 131, 196, 1611, Decimal('488.91'))
# (66, 73, 211, 337, Decimal('914.69'))
# (67, 61, 137, 1046, Decimal('132.00'))
# (68, 114, 144, 548, Decimal('972.02'))
# (69, 116, 298, 1727, Decimal('786.04'))
# (70, 127, 173, 1076, Decimal('878.09'))
# (71, 148, 124, 1434, Decimal('135.42'))
# (72, 86, 140, 1673, Decimal('345.50'))
# (73, 148, 121, 1142, Decimal('337.39'))
# (74, 128, 232, 1589, Decimal('733.70'))
# (75, 120, 71, 1992, Decimal('273.86'))
# (76, 116, 4, 1174, Decimal('772.59'))
# (77, 54, 279, 122, Decimal('359.06'))
# (78, 36, 138, 1181, Decimal('225.06'))
# (79, 35, 226, 264, Decimal('280.24'))
# (80, 114, 186, 1887, Decimal('888.67'))
# (81, 14, 71, 14, Decimal('937.08'))
# (82, 52, 172, 1384, Decimal('90.67'))
# (83, 23, 173, 800, Decimal('16.29'))
# (84, 58, 120, 1154, Decimal('203.35'))
# (85, 107, 147, 338, Decimal('500.02'))
# (86, 105, 293, 140, Decimal('74.29'))
# (87, 58, 227, 1633, Decimal('730.77'))
# (88, 22, 138, 1459, Decimal('53.83'))
# (89, 141, 23, 1278, Decimal('336.00'))
# (90, 147, 270, 63, Decimal('753.21'))
# (91, 30, 158, 541, Decimal('86.63'))
# (92, 122, 151, 191, Decimal('159.17'))
# (93, 46, 195, 1037, Decimal('96.73'))
# (94, 68, 6, 1753, Decimal('359.75'))
# (95, 123, 122, 334, Decimal('249.78'))
# (96, 111, 58, 740, Decimal('902.11'))
# (97, 20, 203, 79, Decimal('77.16'))
# (98, 139, 235, 591, Decimal('210.08'))
# (99, 74, 197, 1773, Decimal('331.69'))
# (100, 71, 87, 700, Decimal('266.57'))
# (101, 114, 148, 1552, Decimal('183.17'))
# (102, 96, 182, 1699, Decimal('803.70'))
# (103, 52, 207, 100, Decimal('548.24'))
# (104, 140, 275, 1467, Decimal('206.97'))
# (105, 145, 163, 1577, Decimal('688.43'))
# (106, 14, 228, 480, Decimal('546.45'))
# (107, 25, 280, 854, Decimal('907.27'))
# (108, 15, 182, 294, Decimal('770.90'))
# (109, 77, 50, 545, Decimal('590.47'))
# (110, 71, 105, 353, Decimal('571.73'))
# (111, 141, 221, 1640, Decimal('980.19'))
# (112, 76, 221, 825, Decimal('365.41'))
# (113, 120, 297, 461, Decimal('126.72'))
# (114, 53, 169, 729, Decimal('333.96'))
# (115, 150, 195, 954, Decimal('411.61'))
# (116, 72, 185, 1506, Decimal('120.50'))
# (117, 41, 167, 589, Decimal('677.13'))
# (118, 43, 24, 427, Decimal('879.58'))
# (119, 28, 258, 269, Decimal('568.43'))
# (120, 100, 29, 1226, Decimal('720.35'))
# (121, 9, 212, 727, Decimal('128.37'))
# (122, 77, 110, 8, Decimal('19.20'))
# (123, 9, 95, 1479, Decimal('992.45'))
# (124, 46, 127, 1394, Decimal('556.74'))
# (125, 137, 202, 285, Decimal('768.07'))
# (126, 32, 101, 1452, Decimal('501.35'))
# (127, 108, 195, 1342, Decimal('829.43'))
# (128, 30, 104, 169, Decimal('428.93'))
# (129, 52, 120, 1237, Decimal('971.14'))
# (130, 52, 87, 552, Decimal('112.88'))
# (131, 120, 249, 62, Decimal('919.66'))
# (132, 82, 173, 1127, Decimal('770.41'))
# (133, 82, 246, 243, Decimal('983.45'))
# (134, 33, 143, 510, Decimal('87.81'))
# (135, 132, 183, 1038, Decimal('204.54'))
# (136, 127, 72, 522, Decimal('117.01'))
# (137, 50, 158, 1616, Decimal('551.64'))
# (138, 80, 41, 379, Decimal('576.32'))
# (139, 120, 12, 1815, Decimal('298.58'))
# (140, 81, 55, 704, Decimal('6.40'))
# (141, 123, 300, 1886, Decimal('209.71'))
# (142, 143, 287, 1773, Decimal('454.30'))
# (143, 3, 150, 813, Decimal('573.31'))
# (144, 71, 291, 2, Decimal('364.61'))
# (145, 28, 252, 1747, Decimal('493.40'))
# (146, 83, 39, 502, Decimal('623.69'))
# (147, 96, 109, 1334, Decimal('651.84'))
# (148, 105, 160, 1807, Decimal('60.94'))
# (149, 20, 196, 1304, Decimal('978.31'))
# (150, 34, 201, 1060, Decimal('250.85'))
